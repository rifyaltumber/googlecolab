# %% [markdown]
# **Mexico Toy Sales**
#
# Sales & inventory data for a fictitious chain of toy stores in Mexico called Maven Toys, including information about products, stores, daily sales transactions, and current inventory levels at each location.
#
# Recommended Analysis
# Which product categories drive the biggest profits? Is this the same across
#
# 1. Which product categories drive the biggest profits? Is this the same across store locations?
# 2. Can you find any seasonal trends or patterns in the sales data?
# 3. Are sales being lost with out-of-stock products at certain locations?
# 4. How much money is tied up in inventory at the toy stores? How long will it last?
#
#
# Source: https://www.mavenanalytics.io/data-playground

# %%
from google.colab import drive

import pandas as pd
import numpy as np

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_1 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/inventory.csv'
path_2 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/products.csv'
path_3 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/stores.csv'
path_4 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/sales.csv'

# %%
inventory = pd.read_csv(path_1)
products = pd.read_csv(path_2)
stores = pd.read_csv(path_3)
sales = pd.read_csv(path_4)

# %%
inventory
# Out:
#       Store_ID  Product_ID  Stock_On_Hand
# 0            1           1             27
# 1            1           2              0
# 2            1           3             32
# 3            1           4              6
# 4            1           5              0
# ...        ...         ...            ...
# 1588        50          31             18
# 1589        50          32              9
# 1590        50          33              1
# 1591        50          34             17
# 1592        50          35              8
#
# [1593 rows x 3 columns]

# %%
products
# Out:
#     Product_ID           Product_Name  ... Product_Cost Product_Price
# 0            1          Action Figure  ...       $9.99        $15.99
# 1            2         Animal Figures  ...       $9.99        $12.99
# 2            3        Barrel O' Slime  ...       $1.99         $3.99
# 3            4       Chutes & Ladders  ...       $9.99        $12.99
# 4            5       Classic Dominoes  ...       $7.99         $9.99
# 5            6              Colorbuds  ...       $6.99        $14.99
# 6            7               Dart Gun  ...      $11.99        $15.99
# 7            8          Deck Of Cards  ...       $3.99         $6.99
# 8            9               Dino Egg  ...       $9.99        $10.99
# 9           10       Dinosaur Figures  ...      $10.99        $14.99
# 10          11          Etch A Sketch  ...      $10.99        $20.99
# 11          12     Foam Disk Launcher  ...       $8.99        $11.99
# 12          13       Gamer Headphones  ...      $14.99        $20.99
# ...

# %%
stores
# Out:
#     Store_ID                     Store_Name  ... Store_Location Store_Open_Date
# 0          1       Maven Toys Guadalajara 1  ...    Residential      1992-09-18
# 1          2         Maven Toys Monterrey 1  ...    Residential      1995-04-27
# 2          3       Maven Toys Guadalajara 2  ...     Commercial      1999-12-27
# 3          4          Maven Toys Saltillo 1  ...       Downtown      2000-01-01
# 4          5            Maven Toys La Paz 1  ...       Downtown      2001-05-31
# 5          6          Maven Toys Mexicali 1  ...     Commercial      2003-12-13
# 6          7         Maven Toys Monterrey 2  ...       Downtown      2003-12-25
# 7          8           Maven Toys Pachuca 1  ...       Downtown      2004-10-14
# 8          9  Maven Toys Ciudad de Mexico 1  ...       Downtown      2004-10-15
# 9         10          Maven Toys Campeche 1  ...       Downtown      2005-01-14
# 10        11        Maven Toys Cuernavaca 1  ...       Downtown      2005-04-19
# ...

# %%
sales
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units
# 0             1  2017-01-01        24           4      1
# 1             2  2017-01-01        28           1      1
# 2             3  2017-01-01         6           8      1
# 3             4  2017-01-01        48           7      1
# 4             5  2017-01-01        44          18      1
# ...         ...         ...       ...         ...    ...
# 829257   829258  2018-09-30        24          19      1
# 829258   829259  2018-09-30        16          35      1
# 829259   829260  2018-09-30        22          19      1
# 829260   829261  2018-09-30        13           2      2
# 829261   829262  2018-09-30        32           6      1
#
# [829262 rows x 5 columns]

# %%
# Soal-1 & 2 (A)
# Which product categories drive the biggest profits? Is this the same across store locations?

data1 = pd.merge(products, sales, on='Product_ID')
data1
# Out:
#         Product_ID   Product_Name Product_Category  ...        Date Store_ID  Units
# 0                1  Action Figure             Toys  ...  2017-01-01       28      1
# 1                1  Action Figure             Toys  ...  2017-01-01       36      1
# 2                1  Action Figure             Toys  ...  2017-01-01       30      3
# 3                1  Action Figure             Toys  ...  2017-01-01       41      1
# 4                1  Action Figure             Toys  ...  2017-01-01       36      1
# ...            ...            ...              ...  ...         ...      ...    ...
# 829257          35  Uno Card Game            Games  ...  2018-09-30       16      1
# 829258          35  Uno Card Game            Games  ...  2018-09-30       16      1
# 829259          35  Uno Card Game            Games  ...  2018-09-30       48      1
# 829260          35  Uno Card Game            Games  ...  2018-09-30       48      1
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 829262 entries, 0 to 829261
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Product_ID        829262 non-null  int64
#  1   Product_Name      829262 non-null  object
#  2   Product_Category  829262 non-null  object
#  3   Product_Cost      829262 non-null  object
#  4   Product_Price     829262 non-null  object
#  5   Sale_ID           829262 non-null  int64
#  6   Date              829262 non-null  object
#  7   Store_ID          829262 non-null  int64
#  8   Units             829262 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 63.3+ MB

# %%
# Soal-1 & 2 (B)
# Which product categories drive the biggest profits? Is this the same across store locations?

data2 = pd.merge(stores, data1, on='Store_ID')
data2
# Out:
#         Store_ID                Store_Name  ...        Date Units
# 0              1  Maven Toys Guadalajara 1  ...  2017-01-02     1
# 1              1  Maven Toys Guadalajara 1  ...  2017-01-02     1
# 2              1  Maven Toys Guadalajara 1  ...  2017-01-02     1
# 3              1  Maven Toys Guadalajara 1  ...  2017-01-02     1
# 4              1  Maven Toys Guadalajara 1  ...  2017-01-02     1
# ...          ...                       ...  ...         ...   ...
# 829257        50   Maven Toys Guanajuato 3  ...  2018-04-03     1
# 829258        50   Maven Toys Guanajuato 3  ...  2018-07-08     1
# 829259        50   Maven Toys Guanajuato 3  ...  2018-09-23     1
# 829260        50   Maven Toys Guanajuato 3  ...  2018-09-23     1
# 829261        50   Maven Toys Guanajuato 3  ...  2018-09-23     1
#
# [829262 rows x 13 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 829262 entries, 0 to 829261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Store_ID          829262 non-null  int64
#  1   Store_Name        829262 non-null  object
#  2   Store_City        829262 non-null  object
#  3   Store_Location    829262 non-null  object
#  4   Store_Open_Date   829262 non-null  object
#  5   Product_ID        829262 non-null  int64
#  6   Product_Name      829262 non-null  object
#  7   Product_Category  829262 non-null  object
#  8   Product_Cost      829262 non-null  object
#  9   Product_Price     829262 non-null  object
#  10  Sale_ID           829262 non-null  int64
#  11  Date              829262 non-null  object
#  12  Units             829262 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 88.6+ MB

# %%
data2.to_csv('/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/Maven-Mexico Toy Sales.csv', index=False, sep=';')
#data2.to_excel('/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/Maven-Mexico Toy Sales.xlsx')
#print("done")

# %%
inventory
# Out:
#       Store_ID  Product_ID  Stock_On_Hand
# 0            1           1             27
# 1            1           2              0
# 2            1           3             32
# 3            1           4              6
# 4            1           5              0
# ...        ...         ...            ...
# 1588        50          31             18
# 1589        50          32              9
# 1590        50          33              1
# 1591        50          34             17
# 1592        50          35              8
#
# [1593 rows x 3 columns]

# %%
inventory.drop('Product_ID', inplace=True, axis=1)

# %%
sales
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units
# 0             1  2017-01-01        24           4      1
# 1             2  2017-01-01        28           1      1
# 2             3  2017-01-01         6           8      1
# 3             4  2017-01-01        48           7      1
# 4             5  2017-01-01        44          18      1
# ...         ...         ...       ...         ...    ...
# 829257   829258  2018-09-30        24          19      1
# 829258   829259  2018-09-30        16          35      1
# 829259   829260  2018-09-30        22          19      1
# 829260   829261  2018-09-30        13           2      2
# 829261   829262  2018-09-30        32           6      1
#
# [829262 rows x 5 columns]

# %%
sales.drop('Product_ID', inplace=True, axis=1)

# %%
sales.drop('Sale_ID', inplace=True, axis=1)

# %%
sales
# Out:
#               Date  Store_ID  Units
# 0       2017-01-01        24      1
# 1       2017-01-01        28      1
# 2       2017-01-01         6      1
# 3       2017-01-01        48      1
# 4       2017-01-01        44      1
# ...            ...       ...    ...
# 829257  2018-09-30        24      1
# 829258  2018-09-30        16      1
# 829259  2018-09-30        22      1
# 829260  2018-09-30        13      2
# 829261  2018-09-30        32      1
#
# [829262 rows x 3 columns]

# %%
stores
# Out:
#     Store_ID                     Store_Name  ... Store_Location Store_Open_Date
# 0          1       Maven Toys Guadalajara 1  ...    Residential      1992-09-18
# 1          2         Maven Toys Monterrey 1  ...    Residential      1995-04-27
# 2          3       Maven Toys Guadalajara 2  ...     Commercial      1999-12-27
# 3          4          Maven Toys Saltillo 1  ...       Downtown      2000-01-01
# 4          5            Maven Toys La Paz 1  ...       Downtown      2001-05-31
# 5          6          Maven Toys Mexicali 1  ...     Commercial      2003-12-13
# 6          7         Maven Toys Monterrey 2  ...       Downtown      2003-12-25
# 7          8           Maven Toys Pachuca 1  ...       Downtown      2004-10-14
# 8          9  Maven Toys Ciudad de Mexico 1  ...       Downtown      2004-10-15
# 9         10          Maven Toys Campeche 1  ...       Downtown      2005-01-14
# 10        11        Maven Toys Cuernavaca 1  ...       Downtown      2005-04-19
# ...

# %%
stores.drop('Store_Name', inplace=True, axis=1)

# %%
stores.drop('Store_City', inplace=True, axis=1)

# %%
stores
# Out:
#     Store_ID Store_Location Store_Open_Date
# 0          1    Residential      1992-09-18
# 1          2    Residential      1995-04-27
# 2          3     Commercial      1999-12-27
# 3          4       Downtown      2000-01-01
# 4          5       Downtown      2001-05-31
# 5          6     Commercial      2003-12-13
# 6          7       Downtown      2003-12-25
# 7          8       Downtown      2004-10-14
# 8          9       Downtown      2004-10-15
# 9         10       Downtown      2005-01-14
# 10        11       Downtown      2005-04-19
# 11        12       Downtown      2006-05-05
# 12        13       Downtown      2006-08-30
# 13        14       Downtown      2007-01-31
# 14        15       Downtown      2007-03-05
# 15        16       Downtown      2007-05-19
# 16        17       Downtown      2007-12-09
# 17        18       Downtown      2008-08-22
# 18        19     Commercial      2008-12-16
# 19        20       Downtown      2009-05-29
# ...

# %%
data3 = pd.merge(sales, inventory, on='Store_ID')
data3
# Out:
#                 Date  Store_ID  Units  Stock_On_Hand
# 0         2017-01-01        24      1             11
# 1         2017-01-01        24      1             25
# 2         2017-01-01        24      1             13
# 3         2017-01-01        24      1              1
# 4         2017-01-01        24      1              4
# ...              ...       ...    ...            ...
# 26405711  2018-09-30        20      1             17
# 26405712  2018-09-30        20      1             10
# 26405713  2018-09-30        20      1              9
# 26405714  2018-09-30        20      1             28
# 26405715  2018-09-30        20      1             19
#
# [26405716 rows x 4 columns]

# %%
data5 = pd.merge(data3, stores, on='Store_ID')
data5
# Out:
#                 Date  Store_ID  ...  Store_Location  Store_Open_Date
# 0         2017-01-01        24  ...        Downtown       2010-07-31
# 1         2017-01-01        24  ...        Downtown       2010-07-31
# 2         2017-01-01        24  ...        Downtown       2010-07-31
# 3         2017-01-01        24  ...        Downtown       2010-07-31
# 4         2017-01-01        24  ...        Downtown       2010-07-31
# ...              ...       ...  ...             ...              ...
# 26405711  2018-09-30        20  ...        Downtown       2009-05-29
# 26405712  2018-09-30        20  ...        Downtown       2009-05-29
# 26405713  2018-09-30        20  ...        Downtown       2009-05-29
# 26405714  2018-09-30        20  ...        Downtown       2009-05-29
# 26405715  2018-09-30        20  ...        Downtown       2009-05-29
#
# [26405716 rows x 6 columns]

# %%
data5.to_csv('/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/Maven-Mexico Toys Inventory.csv', index=False, sep=';')
print("done")
# Out:
# done

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26405716 entries, 0 to 26405715
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Date             object
#  1   Store_ID         int64
#  2   Units            int64
#  3   Stock_On_Hand    int64
#  4   Store_Location   object
#  5   Store_Open_Date  object
# dtypes: int64(3), object(3)
# memory usage: 1.4+ GB
