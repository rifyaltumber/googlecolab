# %% [markdown]
# # Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
path_1 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/inventory.csv'
path_2 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/products.csv'
path_3 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/stores.csv'
path_4 = '/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/sales.csv'

# %%
inventory = pd.read_csv(path_1)
products = pd.read_csv(path_2)
stores = pd.read_csv(path_3)
sales = pd.read_csv(path_4)

# %%
inventory
# Out:
#       Store_ID  Product_ID  Stock_On_Hand
# 0            1           1             27
# 1            1           2              0
# 2            1           3             32
# 3            1           4              6
# 4            1           5              0
# ...        ...         ...            ...
# 1588        50          31             18
# 1589        50          32              9
# 1590        50          33              1
# 1591        50          34             17
# 1592        50          35              8
#
# [1593 rows x 3 columns]

# %%
inventory.drop('Store_ID', inplace=True, axis=1)

# %%
inventory
# Out:
#       Product_ID  Stock_On_Hand
# 0              1             27
# 1              2              0
# 2              3             32
# 3              4              6
# 4              5              0
# ...          ...            ...
# 1588          31             18
# 1589          32              9
# 1590          33              1
# 1591          34             17
# 1592          35              8
#
# [1593 rows x 2 columns]

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1593 entries, 0 to 1592
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product_ID     1593 non-null   int64
#  1   Stock_On_Hand  1593 non-null   int64
# dtypes: int64(2)
# memory usage: 25.0 KB

# %%
products
# Out:
#     Product_ID           Product_Name  ... Product_Cost Product_Price
# 0            1          Action Figure  ...       $9.99        $15.99
# 1            2         Animal Figures  ...       $9.99        $12.99
# 2            3        Barrel O' Slime  ...       $1.99         $3.99
# 3            4       Chutes & Ladders  ...       $9.99        $12.99
# 4            5       Classic Dominoes  ...       $7.99         $9.99
# 5            6              Colorbuds  ...       $6.99        $14.99
# 6            7               Dart Gun  ...      $11.99        $15.99
# 7            8          Deck Of Cards  ...       $3.99         $6.99
# 8            9               Dino Egg  ...       $9.99        $10.99
# 9           10       Dinosaur Figures  ...      $10.99        $14.99
# 10          11          Etch A Sketch  ...      $10.99        $20.99
# 11          12     Foam Disk Launcher  ...       $8.99        $11.99
# 12          13       Gamer Headphones  ...      $14.99        $20.99
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        35 non-null     int64
#  1   Product_Name      35 non-null     object
#  2   Product_Category  35 non-null     object
#  3   Product_Cost      35 non-null     object
#  4   Product_Price     35 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB

# %%
stores
# Out:
#     Store_ID                     Store_Name  ... Store_Location Store_Open_Date
# 0          1       Maven Toys Guadalajara 1  ...    Residential      1992-09-18
# 1          2         Maven Toys Monterrey 1  ...    Residential      1995-04-27
# 2          3       Maven Toys Guadalajara 2  ...     Commercial      1999-12-27
# 3          4          Maven Toys Saltillo 1  ...       Downtown      2000-01-01
# 4          5            Maven Toys La Paz 1  ...       Downtown      2001-05-31
# 5          6          Maven Toys Mexicali 1  ...     Commercial      2003-12-13
# 6          7         Maven Toys Monterrey 2  ...       Downtown      2003-12-25
# 7          8           Maven Toys Pachuca 1  ...       Downtown      2004-10-14
# 8          9  Maven Toys Ciudad de Mexico 1  ...       Downtown      2004-10-15
# 9         10          Maven Toys Campeche 1  ...       Downtown      2005-01-14
# 10        11        Maven Toys Cuernavaca 1  ...       Downtown      2005-04-19
# ...

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store_ID         50 non-null     int64
#  1   Store_Name       50 non-null     object
#  2   Store_City       50 non-null     object
#  3   Store_Location   50 non-null     object
#  4   Store_Open_Date  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
sales
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units
# 0             1  2017-01-01        24           4      1
# 1             2  2017-01-01        28           1      1
# 2             3  2017-01-01         6           8      1
# 3             4  2017-01-01        48           7      1
# 4             5  2017-01-01        44          18      1
# ...         ...         ...       ...         ...    ...
# 829257   829258  2018-09-30        24          19      1
# 829258   829259  2018-09-30        16          35      1
# 829259   829260  2018-09-30        22          19      1
# 829260   829261  2018-09-30        13           2      2
# 829261   829262  2018-09-30        32           6      1
#
# [829262 rows x 5 columns]

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Sale_ID     829262 non-null  int64
#  1   Date        829262 non-null  object
#  2   Store_ID    829262 non-null  int64
#  3   Product_ID  829262 non-null  int64
#  4   Units       829262 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 31.6+ MB

# %%
data1 = pd.merge(sales, stores, on='Store_ID')
data1
# Out:
#         Sale_ID        Date  ...  Store_Location  Store_Open_Date
# 0             1  2017-01-01  ...        Downtown       2010-07-31
# 1            66  2017-01-01  ...        Downtown       2010-07-31
# 2            98  2017-01-01  ...        Downtown       2010-07-31
# 3           106  2017-01-01  ...        Downtown       2010-07-31
# 4           123  2017-01-01  ...        Downtown       2010-07-31
# ...         ...         ...  ...             ...              ...
# 829257   829171  2018-09-30  ...        Downtown       2009-05-29
# 829258   829175  2018-09-30  ...        Downtown       2009-05-29
# 829259   829184  2018-09-30  ...        Downtown       2009-05-29
# 829260   829194  2018-09-30  ...        Downtown       2009-05-29
# 829261   829224  2018-09-30  ...        Downtown       2009-05-29
#
# [829262 rows x 9 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 829262 entries, 0 to 829261
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Sale_ID          829262 non-null  int64
#  1   Date             829262 non-null  object
#  2   Store_ID         829262 non-null  int64
#  3   Product_ID       829262 non-null  int64
#  4   Units            829262 non-null  int64
#  5   Store_Name       829262 non-null  object
#  6   Store_City       829262 non-null  object
#  7   Store_Location   829262 non-null  object
#  8   Store_Open_Date  829262 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 63.3+ MB

# %%
data2 = pd.merge(inventory, products, on='Product_ID')
data2
# Out:
#       Product_ID  Stock_On_Hand  ... Product_Cost Product_Price
# 0              1             27  ...       $9.99        $15.99
# 1              1              0  ...       $9.99        $15.99
# 2              1             17  ...       $9.99        $15.99
# 3              1              2  ...       $9.99        $15.99
# 4              1              8  ...       $9.99        $15.99
# ...          ...            ...  ...          ...           ...
# 1588          35             10  ...       $3.99         $7.99
# 1589          35             13  ...       $3.99         $7.99
# 1590          35              3  ...       $3.99         $7.99
# 1591          35             19  ...       $3.99         $7.99
# 1592          35              8  ...       $3.99         $7.99
#
# [1593 rows x 6 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1593 entries, 0 to 1592
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        1593 non-null   int64
#  1   Stock_On_Hand     1593 non-null   int64
#  2   Product_Name      1593 non-null   object
#  3   Product_Category  1593 non-null   object
#  4   Product_Cost      1593 non-null   object
#  5   Product_Price     1593 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 87.1+ KB

# %%
# data1

for dtype in ['int','object']:
    selected_dtype = data1.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for int columns: 6.33 MB
# Average memory usage for object columns: 46.69 MB

# %%
# data2

for dtype in ['int','object']:
    selected_dtype = data2.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for int columns: 0.01 MB
# Average memory usage for object columns: 0.08 MB

# %%
dataset = pd.merge(data1, data2, on='Product_ID',how='inner')
dataset
# Out:
#           Sale_ID        Date  ...  Product_Cost  Product_Price
# 0               1  2017-01-01  ...        $9.99         $12.99
# 1               1  2017-01-01  ...        $9.99         $12.99
# 2               1  2017-01-01  ...        $9.99         $12.99
# 3               1  2017-01-01  ...        $9.99         $12.99
# 4               1  2017-01-01  ...        $9.99         $12.99
# ...           ...         ...  ...           ...            ...
# 40635898   802860  2018-09-12  ...        $3.99         $10.99
# 40635899   802860  2018-09-12  ...        $3.99         $10.99
# 40635900   802860  2018-09-12  ...        $3.99         $10.99
# 40635901   802860  2018-09-12  ...        $3.99         $10.99
# 40635902   802860  2018-09-12  ...        $3.99         $10.99
#
# [40635903 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40635903 entries, 0 to 40635902
# Data columns (total 14 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Sale_ID           int64
#  1   Date              object
#  2   Store_ID          int64
#  3   Product_ID        int64
#  4   Units             int64
#  5   Store_Name        object
#  6   Store_City        object
#  7   Store_Location    object
#  8   Store_Open_Date   object
#  9   Stock_On_Hand     int64
#  10  Product_Name      object
#  11  Product_Category  object
#  12  Product_Cost      object
#  13  Product_Price     object
# dtypes: int64(5), object(9)
# memory usage: 4.5+ GB

# %%
dataset.to_csv('/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/maven_datatoys.csv', index=False, sep=';')

# %%
#dataset.to_csv('/content/drive/MyDrive/Kumpulan Dataset/2021-Dataset /Maven/Mexico Toy Sales/datatoys.xlsx', index=False, sep=';')

# %%
#dataset.to_csv('maven_datatoys.csv', index=False, sep=';')
